# %%
import cv2
import os
import numpy as np
import random
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from keras.preprocessing.image import load_img, img_to_array, save_img
import imageio
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
import shutil
from tensorflow.keras.backend import clear_session

clear_session()
# Out:
# 2025-06-26 14:42:44.935249: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750938164.946953   13396 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750938164.950513   13396 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-26 14:42:44.963640: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load data path
data_path = "/home/meth/Documents/ETH/DCM/labelled_data"

# %%
all_patients = sorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])
random_seed = 42
tf.random.set_seed(random_seed)
train_val_patients, test_patients = train_test_split(all_patients, test_size=0.1, random_state=random_seed)

train_patients, val_patients = train_test_split(train_val_patients, test_size=50/450, random_state=random_seed)

print(f"Training Patients: {len(train_patients)}")  
print(f"Validation Patients: {len(val_patients)}")  
print(f"Testing Patients: {len(test_patients)}")  
print(f"Total Patients: {len(all_patients)}")
# Out:
# Training Patients: 400
# Validation Patients: 50
# Testing Patients: 50
# Total Patients: 500

# %%
# Create a folder to save test patients
test_patients_folder = "/home/meth/Documents/ETH/DCM/es_test_data" # Change this path as needed
if not os.path.exists(test_patients_folder):
    os.makedirs(test_patients_folder)

# Copy test patients folders to the new test folder
for patient in test_patients:
    patient_path = os.path.join("/home/meth/Documents/ETH/DCM/labelled_data" , patient)  # Adjust this path to your actual patient data location
    if os.path.exists(patient_path):
        dest_path = os.path.join(test_patients_folder, patient)
        shutil.copytree(patient_path, dest_path)
    else:
        print(f"Patient folder {patient} not found.")

print(f"All test patients have been copied to {test_patients_folder}")
# Out:
# All test patients have been copied to /home/meth/Documents/ETH/DCM/es_test_data

# %%
patient_ids = []  
for patient_id in os.listdir(data_path):
    patient_path = os.path.join(data_path, patient_id)
    if os.path.isdir(patient_path):
        patient_ids.append(patient_id)  
print(patient_ids[:3])
# Out:
# ['patient0222', 'patient0320', 'patient0046']

# %%
#function to threshold the mask
def threshold_mask(mask):
    """Convert a grayscale mask to a binary mask with values 0 and 1."""
    _, binary_mask = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)
    binary_mask = binary_mask / 255  # Convert 255 to 1, so values become either 0 or 1
    return binary_mask

# %%
def load_patient_data(patient_ids, root_path, target_size=(256, 256)):
    images, masks = [], []
    
    for patient_id in patient_ids:
        ed_image_dir = os.path.join(root_path, patient_id, "ES", "images")
        ed_mask_dir = os.path.join(root_path, patient_id, "ES", "masks")
        
        if os.path.exists(ed_image_dir) and os.path.exists(ed_mask_dir):
            #print(f"Found images in {ed_image_dir}")
            #print(f"Found masks in {ed_mask_dir}")
            
            image_files = [f for f in os.listdir(ed_image_dir) if f.endswith('.png') and not f.startswith('.')]
            mask_files = [f for f in os.listdir(ed_mask_dir) if f.endswith('.png') and not f.startswith('.')]
            
            #print(f"Image files in {ed_image_dir}: {image_files}")
            #print(f"Mask files in {ed_mask_dir}: {mask_files}")
            
            for image_file in image_files:
                mask_file = image_file.replace('.png', '_gt.png')
                if mask_file in mask_files:
                    img_path = os.path.join(ed_image_dir, image_file)
                    mask_path = os.path.join(ed_mask_dir, mask_file)
                    
                    try:
                        image = Image.open(img_path).convert('RGB')
                        image_resized = image.resize(target_size, Image.BICUBIC)
                        binary_images = np.array(image_resized)
                        normalized_image = binary_images/255
                        images.append(np.array(normalized_image))
                        
                        mask = Image.open(mask_path).convert('L')
                        mask_resized = mask.resize(target_size, Image.NEAREST)
                        mask_binary = np.array(mask_resized)

                        mask_binary = (mask_binary > 128).astype(np.uint8)
                        masks.append(mask_binary)
                    except Exception as e:
                        # print(f"Error loading image or mask {img_path}/{mask_path}: {e}")
                        continue
    
    print(f"Total images loaded: {len(images)}")
    print(f"Total masks loaded: {len(masks)}")
    
    images = np.array(images)
    masks = np.array(masks)
    
    images = images.reshape(-1, 256, 256, 3)
    masks = masks.reshape(-1, 256, 256, 1)
    
    return images, masks

# %%
images, masks = load_patient_data(patient_ids, data_path)
print(f"Number of images loaded: {len(images)}")
print(f"Number of masks loaded: {len(masks)}")
# Out:
# Total images loaded: 500
# Total masks loaded: 500
# Number of images loaded: 500
# Number of masks loaded: 500

# %%
def unet_model(input_shape=(256, 256, 1), learning_rate=1e-4):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D(pool_size=(2, 2))(c4)

    # Bottleneck
    c5 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c5)

    # Decoder
    u6 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c7)

    u8 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c8)

    u9 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1], axis=3)
    c9 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c9)

    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = models.Model(inputs=[inputs], outputs=[outputs])
    
    return model
# Create model
model = unet_model()
model.summary()
# Out:
# W0000 00:00:1750938170.029126   13396 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ conv2d_6[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ conv2d_8[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_10[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,584 │ conv2d_12[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_14[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     18,464 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,248 │ conv2d_16[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         33 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,759,521 (29.60 MB)
#  Trainable params: 7,759,521 (29.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
folds = []
num_folds = 9 
fold_size = len(train_val_patients) // num_folds  

for fold in range(num_folds):
    fold_train_patients = np.concatenate([train_val_patients[:fold * fold_size], train_val_patients[(fold + 1) * fold_size:]])
    fold_val_patients = train_val_patients[fold * fold_size : (fold + 1) * fold_size]

    folds.append((fold_train_patients, fold_val_patients))

dice_scores = []
ious = []

for fold in range(num_folds):
    print(f"\nFold {fold + 1}:")

    fold_train_patients, fold_val_patients = folds[fold]

    X_train, y_train = load_patient_data(fold_train_patients, data_path)
    X_val, y_val = load_patient_data(fold_val_patients, data_path)
    X_test, y_test = load_patient_data(test_patients, data_path) 

    y_train = np.expand_dims(y_train, axis=-1)
    y_val = np.expand_dims(y_val, axis=-1)
    y_test = np.expand_dims(y_test, axis=-1) 

    print(f"Fold Training Patients: {len(fold_train_patients)}")
    print(f"Fold Validation Patients: {len(fold_val_patients)}")

    model = unet_model(input_shape=X_train.shape[1:])

    # Dice loss function
    def dice_loss(y_true, y_pred):
        numerator = 2 * K.sum(y_true * y_pred)
        denominator = K.sum(y_true + y_pred)
        return 1 - numerator / (denominator + K.epsilon())
    
    # def custom_loss(y_true, y_pred):
    #     cross_entropy_loss = tf.keras.losses.BinaryCrossentropy(from_logits=False)(y_true, y_pred)
    #     weight_decay_loss = tf.reduce_sum([tf.nn.l2_loss(w) for w in model.trainable_weights])
    #     return cross_entropy_loss + 1e-4 * weight_decay_loss
# Out:
# Fold 1:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 2:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 3:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 4:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 5:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 6:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 7:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 8:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 9:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50

# %%
# model.compile(optimizer=optimizers.Adam(learning_rate=1e-4), loss=custom_loss, metrics=['accuracy', dice_coefficient, iou_metric])
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss=dice_loss,
                  metrics=['accuracy',dice_coefficient, iou_metric])

checkpoint = ModelCheckpoint(f"unet_fold_{fold + 1}.keras", save_best_only=True, monitor='val_loss', mode='min')
# callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
            #  tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)]

history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=80,
        batch_size=32,
        callbacks=[checkpoint]
    )
# Out:
# Epoch 1/80
# /home/meth/miniconda3/envs/milly/lib/python3.12/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_288']. Received: the structure of inputs=*
#   warnings.warn(
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 118s 9s/step - accuracy: 0.3183 - dice_coefficient: 0.1277 - iou_metric: 0.0682 - loss: 0.8723 - val_accuracy: 0.4716 - val_dice_coefficient: 0.1217 - val_iou_metric: 0.0649 - val_loss: 0.8740
# Epoch 2/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 115s 9s/step - accuracy: 0.4747 - dice_coefficient: 0.1304 - iou_metric: 0.0698 - loss: 0.8696 - val_accuracy: 0.4649 - val_dice_coefficient: 0.1266 - val_iou_metric: 0.0676 - val_loss: 0.8691
# Epoch 3/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 114s 9s/step - accuracy: 0.4241 - dice_coefficient: 0.1385 - iou_metric: 0.0745 - loss: 0.8615 - val_accuracy: 0.0885 - val_dice_coefficient: 0.1528 - val_iou_metric: 0.0828 - val_loss: 0.8418
# Epoch 4/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 115s 9s/step - accuracy: 0.1869 - dice_coefficient: 0.1643 - iou_metric: 0.0896 - loss: 0.8356 - val_accuracy: 0.4676 - val_dice_coefficient: 0.1603 - val_iou_metric: 0.0873 - val_loss: 0.8339
# Epoch 5/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.4911 - dice_coefficient: 0.1742 - iou_metric: 0.0955 - loss: 0.8258 - val_accuracy: 0.5056 - val_dice_coefficient: 0.1804 - val_iou_metric: 0.0993 - val_loss: 0.8130
# Epoch 6/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.5542 - dice_coefficient: 0.2108 - iou_metric: 0.1181 - loss: 0.7896 - val_accuracy: 0.6128 - val_dice_coefficient: 0.2505 - val_iou_metric: 0.1435 - val_loss: 0.7409
# Epoch 7/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.6317 - dice_coefficient: 0.2686 - iou_metric: 0.1554 - loss: 0.7312 - val_accuracy: 0.6161 - val_dice_coefficient: 0.2575 - val_iou_metric: 0.1482 - val_loss: 0.7336
# Epoch 8/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.7494 - dice_coefficient: 0.3619 - iou_metric: 0.2251 - loss: 0.6388 - val_accuracy: 0.8921 - val_dice_coefficient: 0.5062 - val_iou_metric: 0.3403 - val_loss: 0.4804
# Epoch 9/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9088 - dice_coefficient: 0.5492 - iou_metric: 0.3804 - loss: 0.4511 - val_accuracy: 0.9285 - val_dice_coefficient: 0.6099 - val_iou_metric: 0.4407 - val_loss: 0.3759
# Epoch 10/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9393 - dice_coefficient: 0.6521 - iou_metric: 0.4855 - loss: 0.3480 - val_accuracy: 0.9557 - val_dice_coefficient: 0.7129 - val_iou_metric: 0.5546 - val_loss: 0.2790
# Epoch 11/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9574 - dice_coefficient: 0.7305 - iou_metric: 0.5759 - loss: 0.2695 - val_accuracy: 0.9627 - val_dice_coefficient: 0.7484 - val_iou_metric: 0.5985 - val_loss: 0.2455
# Epoch 12/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9647 - dice_coefficient: 0.7644 - iou_metric: 0.6191 - loss: 0.2355 - val_accuracy: 0.9695 - val_dice_coefficient: 0.7685 - val_iou_metric: 0.6248 - val_loss: 0.2241
# Epoch 13/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9696 - dice_coefficient: 0.7918 - iou_metric: 0.6555 - loss: 0.2080 - val_accuracy: 0.9718 - val_dice_coefficient: 0.7878 - val_iou_metric: 0.6508 - val_loss: 0.2045
# Epoch 14/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9731 - dice_coefficient: 0.8158 - iou_metric: 0.6890 - loss: 0.1841 - val_accuracy: 0.9724 - val_dice_coefficient: 0.7988 - val_iou_metric: 0.6661 - val_loss: 0.1924
# Epoch 15/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9750 - dice_coefficient: 0.8295 - iou_metric: 0.7088 - loss: 0.1703 - val_accuracy: 0.9746 - val_dice_coefficient: 0.8116 - val_iou_metric: 0.6836 - val_loss: 0.1816
# Epoch 16/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9767 - dice_coefficient: 0.8407 - iou_metric: 0.7252 - loss: 0.1593 - val_accuracy: 0.9763 - val_dice_coefficient: 0.8265 - val_iou_metric: 0.7045 - val_loss: 0.1697
# Epoch 17/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9785 - dice_coefficient: 0.8524 - iou_metric: 0.7429 - loss: 0.1475 - val_accuracy: 0.9765 - val_dice_coefficient: 0.8296 - val_iou_metric: 0.7093 - val_loss: 0.1649
# Epoch 18/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9789 - dice_coefficient: 0.8563 - iou_metric: 0.7487 - loss: 0.1437 - val_accuracy: 0.9773 - val_dice_coefficient: 0.8363 - val_iou_metric: 0.7192 - val_loss: 0.1579
# Epoch 19/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9794 - dice_coefficient: 0.8600 - iou_metric: 0.7545 - loss: 0.1400 - val_accuracy: 0.9786 - val_dice_coefficient: 0.8433 - val_iou_metric: 0.7292 - val_loss: 0.1544
# Epoch 20/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9804 - dice_coefficient: 0.8643 - iou_metric: 0.7611 - loss: 0.1357 - val_accuracy: 0.9787 - val_dice_coefficient: 0.8459 - val_iou_metric: 0.7334 - val_loss: 0.1492
# Epoch 21/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9806 - dice_coefficient: 0.8677 - iou_metric: 0.7665 - loss: 0.1322 - val_accuracy: 0.9793 - val_dice_coefficient: 0.8518 - val_iou_metric: 0.7422 - val_loss: 0.1437
# Epoch 22/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9807 - dice_coefficient: 0.8678 - iou_metric: 0.7666 - loss: 0.1322 - val_accuracy: 0.9767 - val_dice_coefficient: 0.8394 - val_iou_metric: 0.7239 - val_loss: 0.1547
# Epoch 23/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9803 - dice_coefficient: 0.8669 - iou_metric: 0.7654 - loss: 0.1331 - val_accuracy: 0.9795 - val_dice_coefficient: 0.8533 - val_iou_metric: 0.7446 - val_loss: 0.1414
# Epoch 24/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9807 - dice_coefficient: 0.8711 - iou_metric: 0.7717 - loss: 0.1289 - val_accuracy: 0.9800 - val_dice_coefficient: 0.8562 - val_iou_metric: 0.7489 - val_loss: 0.1388
# Epoch 25/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9816 - dice_coefficient: 0.8754 - iou_metric: 0.7785 - loss: 0.1246 - val_accuracy: 0.9804 - val_dice_coefficient: 0.8604 - val_iou_metric: 0.7552 - val_loss: 0.1363
# Epoch 26/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9820 - dice_coefficient: 0.8788 - iou_metric: 0.7840 - loss: 0.1212 - val_accuracy: 0.9817 - val_dice_coefficient: 0.8678 - val_iou_metric: 0.7665 - val_loss: 0.1301
# Epoch 27/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9827 - dice_coefficient: 0.8833 - iou_metric: 0.7911 - loss: 0.1167 - val_accuracy: 0.9800 - val_dice_coefficient: 0.8585 - val_iou_metric: 0.7524 - val_loss: 0.1376
# Epoch 28/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9826 - dice_coefficient: 0.8822 - iou_metric: 0.7894 - loss: 0.1178 - val_accuracy: 0.9814 - val_dice_coefficient: 0.8680 - val_iou_metric: 0.7669 - val_loss: 0.1289
# Epoch 29/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9831 - dice_coefficient: 0.8866 - iou_metric: 0.7964 - loss: 0.1134 - val_accuracy: 0.9814 - val_dice_coefficient: 0.8672 - val_iou_metric: 0.7656 - val_loss: 0.1304
# Epoch 30/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9834 - dice_coefficient: 0.8874 - iou_metric: 0.7977 - loss: 0.1127 - val_accuracy: 0.9821 - val_dice_coefficient: 0.8722 - val_iou_metric: 0.7735 - val_loss: 0.1248
# Epoch 31/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9837 - dice_coefficient: 0.8900 - iou_metric: 0.8019 - loss: 0.1100 - val_accuracy: 0.9821 - val_dice_coefficient: 0.8730 - val_iou_metric: 0.7750 - val_loss: 0.1227
# Epoch 32/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9838 - dice_coefficient: 0.8912 - iou_metric: 0.8038 - loss: 0.1089 - val_accuracy: 0.9831 - val_dice_coefficient: 0.8781 - val_iou_metric: 0.7828 - val_loss: 0.1186
# Epoch 33/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9842 - dice_coefficient: 0.8938 - iou_metric: 0.8080 - loss: 0.1063 - val_accuracy: 0.9823 - val_dice_coefficient: 0.8736 - val_iou_metric: 0.7757 - val_loss: 0.1237
# Epoch 34/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9844 - dice_coefficient: 0.8944 - iou_metric: 0.8091 - loss: 0.1056 - val_accuracy: 0.9823 - val_dice_coefficient: 0.8749 - val_iou_metric: 0.7777 - val_loss: 0.1221
# Epoch 35/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9844 - dice_coefficient: 0.8947 - iou_metric: 0.8095 - loss: 0.1054 - val_accuracy: 0.9836 - val_dice_coefficient: 0.8817 - val_iou_metric: 0.7886 - val_loss: 0.1154
# Epoch 36/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9849 - dice_coefficient: 0.8976 - iou_metric: 0.8143 - loss: 0.1024 - val_accuracy: 0.9838 - val_dice_coefficient: 0.8833 - val_iou_metric: 0.7912 - val_loss: 0.1139
# Epoch 37/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9853 - dice_coefficient: 0.9002 - iou_metric: 0.8186 - loss: 0.0998 - val_accuracy: 0.9836 - val_dice_coefficient: 0.8823 - val_iou_metric: 0.7895 - val_loss: 0.1147
# Epoch 38/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9854 - dice_coefficient: 0.9011 - iou_metric: 0.8200 - loss: 0.0990 - val_accuracy: 0.9833 - val_dice_coefficient: 0.8814 - val_iou_metric: 0.7882 - val_loss: 0.1153
# Epoch 39/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9855 - dice_coefficient: 0.9015 - iou_metric: 0.8207 - loss: 0.0986 - val_accuracy: 0.9831 - val_dice_coefficient: 0.8805 - val_iou_metric: 0.7867 - val_loss: 0.1167
# Epoch 40/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 115s 9s/step - accuracy: 0.9856 - dice_coefficient: 0.9020 - iou_metric: 0.8216 - loss: 0.0980 - val_accuracy: 0.9828 - val_dice_coefficient: 0.8792 - val_iou_metric: 0.7845 - val_loss: 0.1178
# Epoch 41/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9855 - dice_coefficient: 0.9017 - iou_metric: 0.8211 - loss: 0.0984 - val_accuracy: 0.9827 - val_dice_coefficient: 0.8785 - val_iou_metric: 0.7836 - val_loss: 0.1185
# Epoch 42/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9854 - dice_coefficient: 0.9014 - iou_metric: 0.8206 - loss: 0.0987 - val_accuracy: 0.9834 - val_dice_coefficient: 0.8825 - val_iou_metric: 0.7899 - val_loss: 0.1146
# Epoch 43/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9855 - dice_coefficient: 0.9022 - iou_metric: 0.8219 - loss: 0.0978 - val_accuracy: 0.9854 - val_dice_coefficient: 0.8939 - val_iou_metric: 0.8082 - val_loss: 0.1048
# Epoch 44/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9861 - dice_coefficient: 0.9057 - iou_metric: 0.8278 - loss: 0.0943 - val_accuracy: 0.9848 - val_dice_coefficient: 0.8892 - val_iou_metric: 0.8006 - val_loss: 0.1088
# Epoch 45/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9864 - dice_coefficient: 0.9073 - iou_metric: 0.8304 - loss: 0.0927 - val_accuracy: 0.9844 - val_dice_coefficient: 0.8884 - val_iou_metric: 0.7993 - val_loss: 0.1099
# Epoch 46/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9866 - dice_coefficient: 0.9086 - iou_metric: 0.8326 - loss: 0.0915 - val_accuracy: 0.9853 - val_dice_coefficient: 0.8940 - val_iou_metric: 0.8083 - val_loss: 0.1047
# Epoch 47/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9870 - dice_coefficient: 0.9110 - iou_metric: 0.8367 - loss: 0.0890 - val_accuracy: 0.9851 - val_dice_coefficient: 0.8944 - val_iou_metric: 0.8090 - val_loss: 0.1045
# Epoch 48/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9871 - dice_coefficient: 0.9122 - iou_metric: 0.8387 - loss: 0.0878 - val_accuracy: 0.9855 - val_dice_coefficient: 0.8956 - val_iou_metric: 0.8111 - val_loss: 0.1025
# Epoch 49/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9875 - dice_coefficient: 0.9144 - iou_metric: 0.8424 - loss: 0.0856 - val_accuracy: 0.9854 - val_dice_coefficient: 0.8958 - val_iou_metric: 0.8114 - val_loss: 0.1024
# Epoch 50/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9876 - dice_coefficient: 0.9155 - iou_metric: 0.8442 - loss: 0.0846 - val_accuracy: 0.9856 - val_dice_coefficient: 0.8977 - val_iou_metric: 0.8144 - val_loss: 0.1006
# Epoch 51/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9877 - dice_coefficient: 0.9159 - iou_metric: 0.8450 - loss: 0.0841 - val_accuracy: 0.9854 - val_dice_coefficient: 0.8966 - val_iou_metric: 0.8126 - val_loss: 0.1019
# Epoch 52/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9879 - dice_coefficient: 0.9173 - iou_metric: 0.8474 - loss: 0.0827 - val_accuracy: 0.9854 - val_dice_coefficient: 0.8935 - val_iou_metric: 0.8075 - val_loss: 0.1052
# Epoch 53/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9874 - dice_coefficient: 0.9131 - iou_metric: 0.8401 - loss: 0.0870 - val_accuracy: 0.9838 - val_dice_coefficient: 0.8872 - val_iou_metric: 0.7974 - val_loss: 0.1098
# Epoch 54/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9870 - dice_coefficient: 0.9125 - iou_metric: 0.8392 - loss: 0.0877 - val_accuracy: 0.9847 - val_dice_coefficient: 0.8922 - val_iou_metric: 0.8054 - val_loss: 0.1065
# Epoch 55/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9877 - dice_coefficient: 0.9163 - iou_metric: 0.8456 - loss: 0.0838 - val_accuracy: 0.9851 - val_dice_coefficient: 0.8958 - val_iou_metric: 0.8113 - val_loss: 0.1026
# Epoch 56/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9879 - dice_coefficient: 0.9174 - iou_metric: 0.8475 - loss: 0.0827 - val_accuracy: 0.9858 - val_dice_coefficient: 0.8983 - val_iou_metric: 0.8154 - val_loss: 0.1002
# Epoch 57/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9882 - dice_coefficient: 0.9193 - iou_metric: 0.8507 - loss: 0.0807 - val_accuracy: 0.9854 - val_dice_coefficient: 0.8953 - val_iou_metric: 0.8105 - val_loss: 0.1021
# Epoch 58/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9882 - dice_coefficient: 0.9195 - iou_metric: 0.8511 - loss: 0.0806 - val_accuracy: 0.9852 - val_dice_coefficient: 0.8941 - val_iou_metric: 0.8085 - val_loss: 0.1034
# Epoch 59/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9884 - dice_coefficient: 0.9207 - iou_metric: 0.8532 - loss: 0.0794 - val_accuracy: 0.9858 - val_dice_coefficient: 0.8981 - val_iou_metric: 0.8151 - val_loss: 0.0998
# Epoch 60/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9884 - dice_coefficient: 0.9210 - iou_metric: 0.8535 - loss: 0.0791 - val_accuracy: 0.9861 - val_dice_coefficient: 0.9024 - val_iou_metric: 0.8222 - val_loss: 0.0973
# Epoch 61/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9887 - dice_coefficient: 0.9227 - iou_metric: 0.8565 - loss: 0.0774 - val_accuracy: 0.9857 - val_dice_coefficient: 0.8996 - val_iou_metric: 0.8175 - val_loss: 0.0992
# Epoch 62/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9887 - dice_coefficient: 0.9232 - iou_metric: 0.8574 - loss: 0.0769 - val_accuracy: 0.9863 - val_dice_coefficient: 0.9015 - val_iou_metric: 0.8206 - val_loss: 0.0968
# Epoch 63/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9892 - dice_coefficient: 0.9263 - iou_metric: 0.8627 - loss: 0.0738 - val_accuracy: 0.9858 - val_dice_coefficient: 0.8972 - val_iou_metric: 0.8136 - val_loss: 0.1019
# Epoch 64/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9891 - dice_coefficient: 0.9255 - iou_metric: 0.8614 - loss: 0.0746 - val_accuracy: 0.9861 - val_dice_coefficient: 0.8997 - val_iou_metric: 0.8177 - val_loss: 0.0995
# Epoch 65/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9893 - dice_coefficient: 0.9265 - iou_metric: 0.8631 - loss: 0.0736 - val_accuracy: 0.9857 - val_dice_coefficient: 0.9003 - val_iou_metric: 0.8187 - val_loss: 0.0990
# Epoch 66/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9888 - dice_coefficient: 0.9238 - iou_metric: 0.8584 - loss: 0.0763 - val_accuracy: 0.9857 - val_dice_coefficient: 0.8984 - val_iou_metric: 0.8157 - val_loss: 0.0999
# Epoch 67/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9889 - dice_coefficient: 0.9248 - iou_metric: 0.8601 - loss: 0.0753 - val_accuracy: 0.9859 - val_dice_coefficient: 0.8995 - val_iou_metric: 0.8174 - val_loss: 0.0991
# Epoch 68/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9899 - dice_coefficient: 0.9309 - iou_metric: 0.8708 - loss: 0.0692 - val_accuracy: 0.9861 - val_dice_coefficient: 0.9027 - val_iou_metric: 0.8227 - val_loss: 0.0963
# Epoch 69/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9898 - dice_coefficient: 0.9307 - iou_metric: 0.8704 - loss: 0.0694 - val_accuracy: 0.9860 - val_dice_coefficient: 0.9023 - val_iou_metric: 0.8220 - val_loss: 0.0966
# Epoch 70/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9895 - dice_coefficient: 0.9284 - iou_metric: 0.8665 - loss: 0.0717 - val_accuracy: 0.9867 - val_dice_coefficient: 0.9034 - val_iou_metric: 0.8239 - val_loss: 0.0959
# Epoch 71/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9900 - dice_coefficient: 0.9313 - iou_metric: 0.8714 - loss: 0.0688 - val_accuracy: 0.9862 - val_dice_coefficient: 0.9018 - val_iou_metric: 0.8212 - val_loss: 0.0969
# Epoch 72/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9902 - dice_coefficient: 0.9329 - iou_metric: 0.8743 - loss: 0.0672 - val_accuracy: 0.9834 - val_dice_coefficient: 0.8865 - val_iou_metric: 0.7962 - val_loss: 0.1113
# Epoch 73/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9890 - dice_coefficient: 0.9254 - iou_metric: 0.8614 - loss: 0.0747 - val_accuracy: 0.9861 - val_dice_coefficient: 0.8999 - val_iou_metric: 0.8181 - val_loss: 0.0987
# Epoch 74/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9898 - dice_coefficient: 0.9302 - iou_metric: 0.8696 - loss: 0.0698 - val_accuracy: 0.9858 - val_dice_coefficient: 0.8981 - val_iou_metric: 0.8152 - val_loss: 0.0999
# Epoch 75/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9899 - dice_coefficient: 0.9308 - iou_metric: 0.8706 - loss: 0.0693 - val_accuracy: 0.9851 - val_dice_coefficient: 0.8957 - val_iou_metric: 0.8111 - val_loss: 0.1028
# Epoch 76/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9900 - dice_coefficient: 0.9319 - iou_metric: 0.8725 - loss: 0.0682 - val_accuracy: 0.9854 - val_dice_coefficient: 0.8980 - val_iou_metric: 0.8149 - val_loss: 0.1009
# Epoch 77/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9904 - dice_coefficient: 0.9343 - iou_metric: 0.8767 - loss: 0.0658 - val_accuracy: 0.9853 - val_dice_coefficient: 0.8978 - val_iou_metric: 0.8146 - val_loss: 0.1014
# Epoch 78/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9903 - dice_coefficient: 0.9336 - iou_metric: 0.8755 - loss: 0.0665 - val_accuracy: 0.9855 - val_dice_coefficient: 0.8983 - val_iou_metric: 0.8154 - val_loss: 0.1004
# Epoch 79/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9897 - dice_coefficient: 0.9297 - iou_metric: 0.8687 - loss: 0.0704 - val_accuracy: 0.9852 - val_dice_coefficient: 0.8954 - val_iou_metric: 0.8106 - val_loss: 0.1035
# Epoch 80/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 117s 9s/step - accuracy: 0.9882 - dice_coefficient: 0.9199 - iou_metric: 0.8517 - loss: 0.0802 - val_accuracy: 0.9838 - val_dice_coefficient: 0.8864 - val_iou_metric: 0.7961 - val_loss: 0.1107

# %%
val_loss, val_accuracy, val_dice_score, val_iou = model.evaluate(X_val, y_val)
print(f"Fold {fold + 1} - Validation Loss: {val_loss}, Accuracy: {val_accuracy}, Dice Score: {val_dice_score}, IoU: {val_iou}")

dice_scores.append(val_dice_score)
ious.append(val_iou)

test_loss, test_accuracy, test_dice_score, test_iou = model.evaluate(X_test, y_test)
print(f"Fold {fold + 1} - Test Loss: {test_loss}, Test Accuracy: {test_accuracy}, Test Dice Score: {test_dice_score}, Test IoU: {test_iou}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.9837 - dice_coefficient: 0.8899 - iou_metric: 0.8018 - loss: 0.1081
# Fold 9 - Validation Loss: 0.11065281182527542, Accuracy: 0.9837777614593506, Dice Score: 0.8863643407821655, IoU: 0.7960838675498962
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.9836 - dice_coefficient: 0.8953 - iou_metric: 0.8109 - loss: 0.1080
# Fold 9 - Test Loss: 0.10371807962656021, Test Accuracy: 0.9841504096984863, Test Dice Score: 0.9013074040412903, Test IoU: 0.820831298828125

# %%
mean_dice = np.mean(dice_scores)
std_dice = np.std(dice_scores)
mean_iou = np.mean(ious)
std_iou = np.std(ious)

print(f"Mean Dice Score: {mean_dice}, Standard Deviation: {std_dice}")
print(f"Mean IoU: {mean_iou}, Standard Deviation: {std_iou}")
# Out:
# Mean Dice Score: 0.8863643407821655, Standard Deviation: 0.0
# Mean IoU: 0.7960838675498962, Standard Deviation: 0.0

# %%
model.save(f"es_unet_model_b32_ep80_{mean_dice:.4f}.keras")
