# %%
import cv2
import os
import numpy as np
import random
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from keras.preprocessing.image import load_img, img_to_array, save_img
import imageio
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
import shutil
from tensorflow.keras.backend import clear_session

clear_session()

# %%
# Load data path
data_path = "/home/meth/Documents/ETH/DCM/labelled_data"

# %%
all_patients = sorted([f for f in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, f))])
random_seed = 42
tf.random.set_seed(random_seed)
train_val_patients, test_patients = train_test_split(all_patients, test_size=0.1, random_state=random_seed)

train_patients, val_patients = train_test_split(train_val_patients, test_size=50/450, random_state=random_seed)

print(f"Training Patients: {len(train_patients)}")  
print(f"Validation Patients: {len(val_patients)}")  
print(f"Testing Patients: {len(test_patients)}")  
print(f"Total Patients: {len(all_patients)}")
# Out:
# Training Patients: 400
# Validation Patients: 50
# Testing Patients: 50
# Total Patients: 500

# %%
# Create a folder to save test patients
test_patients_folder = "/home/meth/Documents/ETH/DCM/ed_test_data" # Change this path as needed
if not os.path.exists(test_patients_folder):
    os.makedirs(test_patients_folder)

# Copy test patients folders to the new test folder
for patient in test_patients:
    patient_path = os.path.join("/home/meth/Documents/ETH/DCM/labelled_data" , patient)  # Adjust this path to your actual patient data location
    if os.path.exists(patient_path):
        dest_path = os.path.join(test_patients_folder, patient)
        shutil.copytree(patient_path, dest_path)
    else:
        print(f"Patient folder {patient} not found.")

print(f"All test patients have been copied to {test_patients_folder}")
# Out:
# All test patients have been copied to /home/meth/Documents/ETH/DCM/ed_test_data

# %%
patient_ids = []  
for patient_id in os.listdir(data_path):
    patient_path = os.path.join(data_path, patient_id)
    if os.path.isdir(patient_path):
        patient_ids.append(patient_id)  
print(patient_ids[:3])
# Out:
# ['patient0222', 'patient0320', 'patient0046']

# %%
#function to threshold the mask
def threshold_mask(mask):
    """Convert a grayscale mask to a binary mask with values 0 and 1."""
    _, binary_mask = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)
    binary_mask = binary_mask / 255  # Convert 255 to 1, so values become either 0 or 1
    return binary_mask

# %%
def load_patient_data(patient_ids, root_path, target_size=(256, 256)):
    images, masks = [], []
    
    for patient_id in patient_ids:
        ed_image_dir = os.path.join(root_path, patient_id, "ED", "images")
        ed_mask_dir = os.path.join(root_path, patient_id, "ED", "masks")
        
        if os.path.exists(ed_image_dir) and os.path.exists(ed_mask_dir):
            #print(f"Found images in {ed_image_dir}")
            #print(f"Found masks in {ed_mask_dir}")
            
            image_files = [f for f in os.listdir(ed_image_dir) if f.endswith('.png') and not f.startswith('.')]
            mask_files = [f for f in os.listdir(ed_mask_dir) if f.endswith('.png') and not f.startswith('.')]
            
            #print(f"Image files in {ed_image_dir}: {image_files}")
            #print(f"Mask files in {ed_mask_dir}: {mask_files}")
            
            for image_file in image_files:
                mask_file = image_file.replace('.png', '_gt.png')
                if mask_file in mask_files:
                    img_path = os.path.join(ed_image_dir, image_file)
                    mask_path = os.path.join(ed_mask_dir, mask_file)
                    
                    try:
                        image = Image.open(img_path).convert('RGB')
                        image_resized = image.resize(target_size, Image.BICUBIC)
                        binary_images = np.array(image_resized)
                        normalized_image = binary_images/255
                        images.append(np.array(normalized_image))
                        
                        mask = Image.open(mask_path).convert('L')
                        mask_resized = mask.resize(target_size, Image.NEAREST)
                        mask_binary = np.array(mask_resized)

                        mask_binary = (mask_binary > 128).astype(np.uint8)
                        masks.append(mask_binary)
                    except Exception as e:
                        # print(f"Error loading image or mask {img_path}/{mask_path}: {e}")
                        continue
    
    print(f"Total images loaded: {len(images)}")
    print(f"Total masks loaded: {len(masks)}")
    
    images = np.array(images)
    masks = np.array(masks)
    
    images = images.reshape(-1, 256, 256, 3)
    masks = masks.reshape(-1, 256, 256, 1)
    
    return images, masks

# %%
images, masks = load_patient_data(patient_ids, data_path)
print(f"Number of images loaded: {len(images)}")
print(f"Number of masks loaded: {len(masks)}")
# Out:
# Total images loaded: 500
# Total masks loaded: 500
# Number of images loaded: 500
# Number of masks loaded: 500

# %%
def unet_model(input_shape=(256, 256, 1), learning_rate=1e-4):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D(pool_size=(2, 2))(c4)

    # Bottleneck
    c5 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c5)

    # Decoder
    u6 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c7)

    u8 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c8)

    u9 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1], axis=3)
    c9 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c9)

    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = models.Model(inputs=[inputs], outputs=[outputs])
    
    return model
# Create model
model = unet_model()
model.summary()
# Out:
# W0000 00:00:1749634342.276499    7081 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ conv2d_6[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ conv2d_8[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_10[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,584 │ conv2d_12[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_14[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     18,464 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,248 │ conv2d_16[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         33 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,759,521 (29.60 MB)
#  Trainable params: 7,759,521 (29.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
folds = []
num_folds = 9 
fold_size = len(train_val_patients) // num_folds  

for fold in range(num_folds):
    fold_train_patients = np.concatenate([train_val_patients[:fold * fold_size], train_val_patients[(fold + 1) * fold_size:]])
    fold_val_patients = train_val_patients[fold * fold_size : (fold + 1) * fold_size]

    folds.append((fold_train_patients, fold_val_patients))

dice_scores = []
ious = []

for fold in range(num_folds):
    print(f"\nFold {fold + 1}:")

    fold_train_patients, fold_val_patients = folds[fold]

    X_train, y_train = load_patient_data(fold_train_patients, data_path)
    X_val, y_val = load_patient_data(fold_val_patients, data_path)
    X_test, y_test = load_patient_data(test_patients, data_path) 

    y_train = np.expand_dims(y_train, axis=-1)
    y_val = np.expand_dims(y_val, axis=-1)
    y_test = np.expand_dims(y_test, axis=-1) 

    print(f"Fold Training Patients: {len(fold_train_patients)}")
    print(f"Fold Validation Patients: {len(fold_val_patients)}")

    model = unet_model(input_shape=X_train.shape[1:])

    # Dice loss function
    def dice_loss(y_true, y_pred):
        numerator = 2 * K.sum(y_true * y_pred)
        denominator = K.sum(y_true + y_pred)
        return 1 - numerator / (denominator + K.epsilon())
    
    # def custom_loss(y_true, y_pred):
    #     cross_entropy_loss = tf.keras.losses.BinaryCrossentropy(from_logits=False)(y_true, y_pred)
    #     weight_decay_loss = tf.reduce_sum([tf.nn.l2_loss(w) for w in model.trainable_weights])
    #     return cross_entropy_loss + 1e-4 * weight_decay_loss
# Out:
# Fold 1:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 2:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 3:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 4:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 5:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 6:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 7:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 8:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50
#
# Fold 9:
# Total images loaded: 400
# Total masks loaded: 400
# Total images loaded: 50
# Total masks loaded: 50
# Total images loaded: 50
# Total masks loaded: 50
# Fold Training Patients: 400
# Fold Validation Patients: 50

# %%
# model.compile(optimizer=optimizers.Adam(learning_rate=1e-4), loss=custom_loss, metrics=['accuracy', dice_coefficient, iou_metric])
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss=dice_loss,
                  metrics=['accuracy',dice_coefficient, iou_metric])

checkpoint = ModelCheckpoint(f"unet_fold_{fold + 1}.keras", save_best_only=True, monitor='val_loss', mode='min')

history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=80,
        batch_size=8,
        callbacks=[checkpoint]
    )
# Out:
# Epoch 1/80
# /home/meth/miniconda3/envs/milly/lib/python3.12/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_288']. Received: the structure of inputs=*
#   warnings.warn(
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.5574 - dice_coefficient: 0.1835 - iou_metric: 0.1012 - loss: 0.8165 - val_accuracy: 0.5637 - val_dice_coefficient: 0.2230 - val_iou_metric: 0.1256 - val_loss: 0.7724
# Epoch 2/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.6611 - dice_coefficient: 0.3598 - iou_metric: 0.2287 - loss: 0.6402 - val_accuracy: 0.9206 - val_dice_coefficient: 0.6633 - val_iou_metric: 0.4967 - val_loss: 0.3405
# Epoch 3/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9208 - dice_coefficient: 0.6736 - iou_metric: 0.5091 - loss: 0.3264 - val_accuracy: 0.9230 - val_dice_coefficient: 0.7012 - val_iou_metric: 0.5402 - val_loss: 0.3011
# Epoch 4/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9373 - dice_coefficient: 0.7287 - iou_metric: 0.5743 - loss: 0.2713 - val_accuracy: 0.9568 - val_dice_coefficient: 0.8010 - val_iou_metric: 0.6682 - val_loss: 0.1984
# Epoch 5/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9593 - dice_coefficient: 0.8143 - iou_metric: 0.6879 - loss: 0.1857 - val_accuracy: 0.9626 - val_dice_coefficient: 0.8309 - val_iou_metric: 0.7113 - val_loss: 0.1644
# Epoch 6/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9668 - dice_coefficient: 0.8480 - iou_metric: 0.7371 - loss: 0.1520 - val_accuracy: 0.9699 - val_dice_coefficient: 0.8730 - val_iou_metric: 0.7750 - val_loss: 0.1305
# Epoch 7/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9747 - dice_coefficient: 0.8854 - iou_metric: 0.7952 - loss: 0.1146 - val_accuracy: 0.9740 - val_dice_coefficient: 0.8881 - val_iou_metric: 0.7991 - val_loss: 0.1137
# Epoch 8/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9777 - dice_coefficient: 0.8986 - iou_metric: 0.8164 - loss: 0.1014 - val_accuracy: 0.9745 - val_dice_coefficient: 0.8946 - val_iou_metric: 0.8097 - val_loss: 0.1083
# Epoch 9/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9785 - dice_coefficient: 0.9034 - iou_metric: 0.8242 - loss: 0.0966 - val_accuracy: 0.9760 - val_dice_coefficient: 0.9019 - val_iou_metric: 0.8219 - val_loss: 0.1018
# Epoch 10/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9804 - dice_coefficient: 0.9120 - iou_metric: 0.8388 - loss: 0.0880 - val_accuracy: 0.9761 - val_dice_coefficient: 0.9031 - val_iou_metric: 0.8237 - val_loss: 0.1000
# Epoch 11/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9811 - dice_coefficient: 0.9150 - iou_metric: 0.8437 - loss: 0.0850 - val_accuracy: 0.9760 - val_dice_coefficient: 0.9021 - val_iou_metric: 0.8220 - val_loss: 0.1013
# Epoch 12/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9816 - dice_coefficient: 0.9173 - iou_metric: 0.8476 - loss: 0.0827 - val_accuracy: 0.9783 - val_dice_coefficient: 0.9110 - val_iou_metric: 0.8370 - val_loss: 0.0924
# Epoch 13/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9825 - dice_coefficient: 0.9215 - iou_metric: 0.8548 - loss: 0.0785 - val_accuracy: 0.9780 - val_dice_coefficient: 0.9096 - val_iou_metric: 0.8348 - val_loss: 0.0944
# Epoch 14/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9823 - dice_coefficient: 0.9198 - iou_metric: 0.8519 - loss: 0.0802 - val_accuracy: 0.9788 - val_dice_coefficient: 0.9119 - val_iou_metric: 0.8386 - val_loss: 0.0913
# Epoch 15/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9834 - dice_coefficient: 0.9253 - iou_metric: 0.8612 - loss: 0.0747 - val_accuracy: 0.9796 - val_dice_coefficient: 0.9147 - val_iou_metric: 0.8431 - val_loss: 0.0875
# Epoch 16/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9838 - dice_coefficient: 0.9273 - iou_metric: 0.8648 - loss: 0.0727 - val_accuracy: 0.9807 - val_dice_coefficient: 0.9191 - val_iou_metric: 0.8506 - val_loss: 0.0830
# Epoch 17/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9845 - dice_coefficient: 0.9302 - iou_metric: 0.8697 - loss: 0.0698 - val_accuracy: 0.9811 - val_dice_coefficient: 0.9206 - val_iou_metric: 0.8533 - val_loss: 0.0822
# Epoch 18/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9849 - dice_coefficient: 0.9319 - iou_metric: 0.8726 - loss: 0.0681 - val_accuracy: 0.9821 - val_dice_coefficient: 0.9242 - val_iou_metric: 0.8595 - val_loss: 0.0785
# Epoch 19/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9856 - dice_coefficient: 0.9351 - iou_metric: 0.8782 - loss: 0.0649 - val_accuracy: 0.9819 - val_dice_coefficient: 0.9242 - val_iou_metric: 0.8594 - val_loss: 0.0785
# Epoch 20/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9860 - dice_coefficient: 0.9370 - iou_metric: 0.8817 - loss: 0.0630 - val_accuracy: 0.9821 - val_dice_coefficient: 0.9246 - val_iou_metric: 0.8600 - val_loss: 0.0764
# Epoch 21/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9865 - dice_coefficient: 0.9392 - iou_metric: 0.8856 - loss: 0.0608 - val_accuracy: 0.9813 - val_dice_coefficient: 0.9223 - val_iou_metric: 0.8562 - val_loss: 0.0801
# Epoch 22/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9866 - dice_coefficient: 0.9400 - iou_metric: 0.8870 - loss: 0.0600 - val_accuracy: 0.9820 - val_dice_coefficient: 0.9262 - val_iou_metric: 0.8630 - val_loss: 0.0766
# Epoch 23/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9865 - dice_coefficient: 0.9392 - iou_metric: 0.8855 - loss: 0.0608 - val_accuracy: 0.9806 - val_dice_coefficient: 0.9196 - val_iou_metric: 0.8516 - val_loss: 0.0823
# Epoch 24/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9867 - dice_coefficient: 0.9402 - iou_metric: 0.8873 - loss: 0.0598 - val_accuracy: 0.9819 - val_dice_coefficient: 0.9244 - val_iou_metric: 0.8598 - val_loss: 0.0778
# Epoch 25/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9865 - dice_coefficient: 0.9395 - iou_metric: 0.8861 - loss: 0.0605 - val_accuracy: 0.9822 - val_dice_coefficient: 0.9245 - val_iou_metric: 0.8600 - val_loss: 0.0771
# Epoch 26/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9873 - dice_coefficient: 0.9424 - iou_metric: 0.8912 - loss: 0.0576 - val_accuracy: 0.9836 - val_dice_coefficient: 0.9306 - val_iou_metric: 0.8705 - val_loss: 0.0716
# Epoch 27/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9877 - dice_coefficient: 0.9445 - iou_metric: 0.8949 - loss: 0.0555 - val_accuracy: 0.9818 - val_dice_coefficient: 0.9235 - val_iou_metric: 0.8583 - val_loss: 0.0794
# Epoch 28/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9871 - dice_coefficient: 0.9412 - iou_metric: 0.8892 - loss: 0.0588 - val_accuracy: 0.9845 - val_dice_coefficient: 0.9343 - val_iou_metric: 0.8770 - val_loss: 0.0675
# Epoch 29/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9881 - dice_coefficient: 0.9461 - iou_metric: 0.8978 - loss: 0.0539 - val_accuracy: 0.9835 - val_dice_coefficient: 0.9292 - val_iou_metric: 0.8680 - val_loss: 0.0720
# Epoch 30/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9881 - dice_coefficient: 0.9464 - iou_metric: 0.8985 - loss: 0.0536 - val_accuracy: 0.9848 - val_dice_coefficient: 0.9344 - val_iou_metric: 0.8770 - val_loss: 0.0668
# Epoch 31/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9888 - dice_coefficient: 0.9493 - iou_metric: 0.9037 - loss: 0.0507 - val_accuracy: 0.9844 - val_dice_coefficient: 0.9326 - val_iou_metric: 0.8738 - val_loss: 0.0687
# Epoch 32/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9885 - dice_coefficient: 0.9482 - iou_metric: 0.9015 - loss: 0.0518 - val_accuracy: 0.9846 - val_dice_coefficient: 0.9348 - val_iou_metric: 0.8777 - val_loss: 0.0668
# Epoch 33/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9892 - dice_coefficient: 0.9512 - iou_metric: 0.9070 - loss: 0.0488 - val_accuracy: 0.9835 - val_dice_coefficient: 0.9301 - val_iou_metric: 0.8696 - val_loss: 0.0722
# Epoch 34/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9889 - dice_coefficient: 0.9499 - iou_metric: 0.9047 - loss: 0.0501 - val_accuracy: 0.9837 - val_dice_coefficient: 0.9321 - val_iou_metric: 0.8730 - val_loss: 0.0698
# Epoch 35/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9892 - dice_coefficient: 0.9509 - iou_metric: 0.9065 - loss: 0.0491 - val_accuracy: 0.9843 - val_dice_coefficient: 0.9336 - val_iou_metric: 0.8757 - val_loss: 0.0680
# Epoch 36/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9892 - dice_coefficient: 0.9514 - iou_metric: 0.9074 - loss: 0.0486 - val_accuracy: 0.9841 - val_dice_coefficient: 0.9333 - val_iou_metric: 0.8752 - val_loss: 0.0687
# Epoch 37/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9896 - dice_coefficient: 0.9533 - iou_metric: 0.9108 - loss: 0.0467 - val_accuracy: 0.9835 - val_dice_coefficient: 0.9311 - val_iou_metric: 0.8713 - val_loss: 0.0704
# Epoch 38/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9893 - dice_coefficient: 0.9522 - iou_metric: 0.9088 - loss: 0.0478 - val_accuracy: 0.9847 - val_dice_coefficient: 0.9353 - val_iou_metric: 0.8787 - val_loss: 0.0660
# Epoch 39/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9889 - dice_coefficient: 0.9505 - iou_metric: 0.9057 - loss: 0.0495 - val_accuracy: 0.9837 - val_dice_coefficient: 0.9304 - val_iou_metric: 0.8700 - val_loss: 0.0692
# Epoch 40/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9891 - dice_coefficient: 0.9513 - iou_metric: 0.9071 - loss: 0.0487 - val_accuracy: 0.9838 - val_dice_coefficient: 0.9325 - val_iou_metric: 0.8737 - val_loss: 0.0701
# Epoch 41/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9895 - dice_coefficient: 0.9528 - iou_metric: 0.9099 - loss: 0.0472 - val_accuracy: 0.9834 - val_dice_coefficient: 0.9286 - val_iou_metric: 0.8668 - val_loss: 0.0716
# Epoch 42/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9893 - dice_coefficient: 0.9518 - iou_metric: 0.9082 - loss: 0.0482 - val_accuracy: 0.9808 - val_dice_coefficient: 0.9147 - val_iou_metric: 0.8434 - val_loss: 0.0801
# Epoch 43/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9890 - dice_coefficient: 0.9505 - iou_metric: 0.9058 - loss: 0.0495 - val_accuracy: 0.9836 - val_dice_coefficient: 0.9253 - val_iou_metric: 0.8616 - val_loss: 0.0697
# Epoch 44/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9892 - dice_coefficient: 0.9513 - iou_metric: 0.9072 - loss: 0.0487 - val_accuracy: 0.9847 - val_dice_coefficient: 0.9357 - val_iou_metric: 0.8794 - val_loss: 0.0658
# Epoch 45/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9894 - dice_coefficient: 0.9524 - iou_metric: 0.9092 - loss: 0.0476 - val_accuracy: 0.9853 - val_dice_coefficient: 0.9376 - val_iou_metric: 0.8827 - val_loss: 0.0641
# Epoch 46/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9907 - dice_coefficient: 0.9579 - iou_metric: 0.9194 - loss: 0.0421 - val_accuracy: 0.9848 - val_dice_coefficient: 0.9334 - val_iou_metric: 0.8753 - val_loss: 0.0664
# Epoch 47/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9915 - dice_coefficient: 0.9617 - iou_metric: 0.9264 - loss: 0.0383 - val_accuracy: 0.9846 - val_dice_coefficient: 0.9322 - val_iou_metric: 0.8731 - val_loss: 0.0676
# Epoch 48/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9918 - dice_coefficient: 0.9629 - iou_metric: 0.9285 - loss: 0.0371 - val_accuracy: 0.9850 - val_dice_coefficient: 0.9355 - val_iou_metric: 0.8790 - val_loss: 0.0649
# Epoch 49/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9917 - dice_coefficient: 0.9624 - iou_metric: 0.9276 - loss: 0.0376 - val_accuracy: 0.9844 - val_dice_coefficient: 0.9330 - val_iou_metric: 0.8746 - val_loss: 0.0667
# Epoch 50/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9917 - dice_coefficient: 0.9626 - iou_metric: 0.9280 - loss: 0.0374 - val_accuracy: 0.9854 - val_dice_coefficient: 0.9384 - val_iou_metric: 0.8842 - val_loss: 0.0631
# Epoch 51/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9917 - dice_coefficient: 0.9625 - iou_metric: 0.9278 - loss: 0.0375 - val_accuracy: 0.9855 - val_dice_coefficient: 0.9385 - val_iou_metric: 0.8843 - val_loss: 0.0637
# Epoch 52/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9923 - dice_coefficient: 0.9652 - iou_metric: 0.9328 - loss: 0.0348 - val_accuracy: 0.9845 - val_dice_coefficient: 0.9334 - val_iou_metric: 0.8753 - val_loss: 0.0672
# Epoch 53/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9919 - dice_coefficient: 0.9633 - iou_metric: 0.9292 - loss: 0.0367 - val_accuracy: 0.9837 - val_dice_coefficient: 0.9299 - val_iou_metric: 0.8692 - val_loss: 0.0692
# Epoch 54/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9916 - dice_coefficient: 0.9622 - iou_metric: 0.9272 - loss: 0.0378 - val_accuracy: 0.9828 - val_dice_coefficient: 0.9265 - val_iou_metric: 0.8633 - val_loss: 0.0721
# Epoch 55/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9919 - dice_coefficient: 0.9635 - iou_metric: 0.9295 - loss: 0.0365 - val_accuracy: 0.9796 - val_dice_coefficient: 0.9112 - val_iou_metric: 0.8376 - val_loss: 0.0836
# Epoch 56/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9906 - dice_coefficient: 0.9578 - iou_metric: 0.9191 - loss: 0.0422 - val_accuracy: 0.9828 - val_dice_coefficient: 0.9286 - val_iou_metric: 0.8669 - val_loss: 0.0721
# Epoch 57/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9912 - dice_coefficient: 0.9602 - iou_metric: 0.9236 - loss: 0.0398 - val_accuracy: 0.9843 - val_dice_coefficient: 0.9350 - val_iou_metric: 0.8782 - val_loss: 0.0665
# Epoch 58/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9914 - dice_coefficient: 0.9613 - iou_metric: 0.9255 - loss: 0.0387 - val_accuracy: 0.9856 - val_dice_coefficient: 0.9390 - val_iou_metric: 0.8851 - val_loss: 0.0627
# Epoch 59/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9927 - dice_coefficient: 0.9670 - iou_metric: 0.9362 - loss: 0.0330 - val_accuracy: 0.9849 - val_dice_coefficient: 0.9376 - val_iou_metric: 0.8828 - val_loss: 0.0645
# Epoch 60/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9936 - dice_coefficient: 0.9709 - iou_metric: 0.9435 - loss: 0.0291 - val_accuracy: 0.9840 - val_dice_coefficient: 0.9345 - val_iou_metric: 0.8773 - val_loss: 0.0679
# Epoch 61/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9935 - dice_coefficient: 0.9708 - iou_metric: 0.9432 - loss: 0.0292 - val_accuracy: 0.9830 - val_dice_coefficient: 0.9300 - val_iou_metric: 0.8694 - val_loss: 0.0709
# Epoch 62/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9937 - dice_coefficient: 0.9717 - iou_metric: 0.9450 - loss: 0.0283 - val_accuracy: 0.9825 - val_dice_coefficient: 0.9293 - val_iou_metric: 0.8682 - val_loss: 0.0726
# Epoch 63/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9931 - dice_coefficient: 0.9686 - iou_metric: 0.9392 - loss: 0.0314 - val_accuracy: 0.9844 - val_dice_coefficient: 0.9365 - val_iou_metric: 0.8810 - val_loss: 0.0661
# Epoch 64/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9928 - dice_coefficient: 0.9674 - iou_metric: 0.9369 - loss: 0.0326 - val_accuracy: 0.9831 - val_dice_coefficient: 0.9305 - val_iou_metric: 0.8704 - val_loss: 0.0711
# Epoch 65/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9934 - dice_coefficient: 0.9700 - iou_metric: 0.9419 - loss: 0.0300 - val_accuracy: 0.9835 - val_dice_coefficient: 0.9336 - val_iou_metric: 0.8759 - val_loss: 0.0691
# Epoch 66/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9926 - dice_coefficient: 0.9668 - iou_metric: 0.9358 - loss: 0.0332 - val_accuracy: 0.9834 - val_dice_coefficient: 0.9335 - val_iou_metric: 0.8758 - val_loss: 0.0694
# Epoch 67/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9936 - dice_coefficient: 0.9711 - iou_metric: 0.9438 - loss: 0.0289 - val_accuracy: 0.9829 - val_dice_coefficient: 0.9295 - val_iou_metric: 0.8687 - val_loss: 0.0724
# Epoch 68/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9932 - dice_coefficient: 0.9693 - iou_metric: 0.9404 - loss: 0.0307 - val_accuracy: 0.9843 - val_dice_coefficient: 0.9344 - val_iou_metric: 0.8773 - val_loss: 0.0673
# Epoch 69/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9922 - dice_coefficient: 0.9648 - iou_metric: 0.9320 - loss: 0.0352 - val_accuracy: 0.9827 - val_dice_coefficient: 0.9242 - val_iou_metric: 0.8593 - val_loss: 0.0787
# Epoch 70/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9902 - dice_coefficient: 0.9556 - iou_metric: 0.9151 - loss: 0.0444 - val_accuracy: 0.9837 - val_dice_coefficient: 0.9261 - val_iou_metric: 0.8625 - val_loss: 0.0741
# Epoch 71/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9917 - dice_coefficient: 0.9624 - iou_metric: 0.9276 - loss: 0.0376 - val_accuracy: 0.9842 - val_dice_coefficient: 0.9285 - val_iou_metric: 0.8666 - val_loss: 0.0716
# Epoch 72/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9924 - dice_coefficient: 0.9657 - iou_metric: 0.9337 - loss: 0.0343 - val_accuracy: 0.9854 - val_dice_coefficient: 0.9344 - val_iou_metric: 0.8770 - val_loss: 0.0658
# Epoch 73/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9931 - dice_coefficient: 0.9688 - iou_metric: 0.9396 - loss: 0.0312 - val_accuracy: 0.9856 - val_dice_coefficient: 0.9368 - val_iou_metric: 0.8812 - val_loss: 0.0639
# Epoch 74/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9937 - dice_coefficient: 0.9714 - iou_metric: 0.9445 - loss: 0.0286 - val_accuracy: 0.9858 - val_dice_coefficient: 0.9409 - val_iou_metric: 0.8886 - val_loss: 0.0611
# Epoch 75/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9944 - dice_coefficient: 0.9745 - iou_metric: 0.9503 - loss: 0.0255 - val_accuracy: 0.9851 - val_dice_coefficient: 0.9389 - val_iou_metric: 0.8852 - val_loss: 0.0636
# Epoch 76/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9948 - dice_coefficient: 0.9764 - iou_metric: 0.9539 - loss: 0.0236 - val_accuracy: 0.9845 - val_dice_coefficient: 0.9342 - val_iou_metric: 0.8769 - val_loss: 0.0673
# Epoch 77/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9945 - dice_coefficient: 0.9750 - iou_metric: 0.9513 - loss: 0.0250 - val_accuracy: 0.9821 - val_dice_coefficient: 0.9206 - val_iou_metric: 0.8530 - val_loss: 0.0812
# Epoch 78/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9928 - dice_coefficient: 0.9673 - iou_metric: 0.9367 - loss: 0.0327 - val_accuracy: 0.9834 - val_dice_coefficient: 0.9259 - val_iou_metric: 0.8622 - val_loss: 0.0757
# Epoch 79/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9934 - dice_coefficient: 0.9703 - iou_metric: 0.9424 - loss: 0.0297 - val_accuracy: 0.9848 - val_dice_coefficient: 0.9339 - val_iou_metric: 0.8762 - val_loss: 0.0680
# Epoch 80/80
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9945 - dice_coefficient: 0.9752 - iou_metric: 0.9517 - loss: 0.0248 - val_accuracy: 0.9852 - val_dice_coefficient: 0.9358 - val_iou_metric: 0.8795 - val_loss: 0.0661

# %%
val_loss, val_accuracy, val_dice_score, val_iou = model.evaluate(X_val, y_val)
print(f"Fold {fold + 1} - Validation Loss: {val_loss}, Accuracy: {val_accuracy}, Dice Score: {val_dice_score}, IoU: {val_iou}")

dice_scores.append(val_dice_score)
ious.append(val_iou)

test_loss, test_accuracy, test_dice_score, test_iou = model.evaluate(X_test, y_test)
print(f"Fold {fold + 1} - Test Loss: {test_loss}, Test Accuracy: {test_accuracy}, Test Dice Score: {test_dice_score}, Test IoU: {test_iou}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.9848 - dice_coefficient: 0.9335 - iou_metric: 0.8754 - loss: 0.0667
# Fold 9 - Validation Loss: 0.06638483703136444, Accuracy: 0.9851678609848022, Dice Score: 0.9340391159057617, IoU: 0.8762452602386475
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.9863 - dice_coefficient: 0.9389 - iou_metric: 0.8848 - loss: 0.0607
# Fold 9 - Test Loss: 0.06125675514340401, Test Accuracy: 0.986096203327179, Test Dice Score: 0.9380679130554199, Test IoU: 0.8833693861961365

# %%
mean_dice = np.mean(dice_scores)
std_dice = np.std(dice_scores)
mean_iou = np.mean(ious)
std_iou = np.std(ious)

print(f"Mean Dice Score: {mean_dice}, Standard Deviation: {std_dice}")
print(f"Mean IoU: {mean_iou}, Standard Deviation: {std_iou}")
# Out:
# Mean Dice Score: 0.9340391159057617, Standard Deviation: 0.0
# Mean IoU: 0.8762452602386475, Standard Deviation: 0.0

# %%
model.save(f"ed_unet_model_b8_ep80_{mean_dice:.4f}.keras")
